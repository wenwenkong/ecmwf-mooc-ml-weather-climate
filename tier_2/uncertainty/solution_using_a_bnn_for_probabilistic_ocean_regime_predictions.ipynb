# %% [markdown]
# # [Tutorial](https://github.com/ecmwf-projects/mooc-machine-learning-weather-climate/blob/main/tier_2/uncertainty/solution_using_a_bnn_for_probabilistic_ocean_regime_predictions.ipynb)
#
# # Using a BNN for probabilistic ocean regime predictions
# ### SOLUTION
#
# The exercise below is based on the work done in
#
# Clare et al. (2022) *Explainable Artificial Intelligence for Bayesian Neural Networks: Toward Trustworthy Predictions of Ocean Dynamics* Journal of Advances in Modeling Earth Systems 14 (11), e2022MS003162 [link](https://agupubs.onlinelibrary.wiley.com/doi/full/10.1029/2022MS003162)
#
# In that paper, a Bayesian Neural Network was used to make a probabilistic prediction of ocean circulation regimes. You will learn more about this dataset and how the ocean regimes were identified from Maike Sonnewald in Tier 3. Note that Clare et al. (2022) builds on work in [Sonnewald & Lguensat (2021)](https://doi.org/10.1029/2021MS002496) who built a deterministic neural network for the same problem and [Sonnewald et al. (2019)](https://doi.org/10.1029/2018ea000519), where the ocean regimes were first identified by k-means clustering.
#
# The input features for our neural network are as follows:
#
# 1.   Wind stress curl
# 2.   Mean Sea Surface Height (SSH) (20 years)
# 3.   Gradients of Mean Sea Surface Height
# 4.   Bathymetry
# 5.   Gradients of bathymetry
# 6.   Coriolis
#
# For justification of this choice of these features please see Sonnewald & Lguensat (2021).

# %% [markdown]
# ## How to run this exercise
#
# This exercise is in the form of a [Jupyter notebook](https://jupyter.org/). It can be run in a number of free cloud based environments (see two options below). These require no installation. When you click on one of the links below ("Open in Colab" or "Open in Kaggle") you will be prompted to create a free account, after which you will see the same page you see here. Follow the instructions below to connect to a GPU. After that you can run each block of code by selecting shift+control repeatedly, or by selecting the "play" icon.
#
# Advanced users may wish to run this exercise on their own computers by first installing Python and Jupyter, in addition to the packages listed below (numpy, xarray, scipy and matplotlib).

# %% [markdown]
# <style>
# td, th {
#    border: 1px solid white;
#    border-collapse: collapse;
# }
# </style>
# <table align="left">
#   <tr>
#     <th>Run the tutorial via free cloud platforms: </th>
#     <th><a href="https://colab.research.google.com/github/ecmwf-projects/mooc-machine-learning-weather-climate/blob/main/tier_2/uncertainty/solution_using_a_bnn_for_probabilistic_ocean_regime_predictions.ipynb">
#         <img src = "https://colab.research.google.com/assets/colab-badge.svg" alt = "Colab"></th>
#     <th><a href="https://kaggle.com/kernels/welcome?src=https://github.com/ecmwf-projects/mooc-machine-learning-weather-climate/blob/main/tier_2/uncertainty/solution_using_a_bnn_for_probabilistic_ocean_regime_predictions.ipynb">
#         <img src = "https://kaggle.com/static/images/open-in-kaggle.svg" alt = "Kaggle"></th>
#   </tr>
# </table>

# %% [markdown]
# Note that to use Kaggle, you need to enable an option on the notebook. Please follow the instructions here to do this https://stackoverflow.com/questions/68142524/cannot-access-internet-on-kaggle-notebook.
#
# Since we will train a neural network later, it might make sense to connect to a GPU runtime:
#
# *   In Google Colab this can be done under Runtime --> Change runtime type.
#
# *   In Kaggle this can be done under Accelerator.

# %% [markdown]
# ## Import packages

# %%
## Import standard packages for reading data and plotting
import numpy as np
import xarray as xr
from scipy.io import loadmat
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load and process data

# %%
## Download input Data
! wget https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/kCluster6.npy
! wget https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/curlTau.npy
! wget https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.1992.nc
! wget https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.1993.nc
! wget https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.1994.nc
! wget https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.1995.nc
! wget https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.1996.nc
! wget https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.1997.nc
! wget https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.1998.nc
! wget https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.1999.nc
! wget https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.2000.nc
! wget https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.2001.nc
! wget https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.2002.nc
! wget https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.2003.nc
! wget https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.2004.nc
! wget https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.2005.nc
! wget https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.2006.nc
! wget https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.2007.nc
! wget https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.2008.nc
! wget https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.2009.nc
! wget https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.2010.nc 
! wget https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.2011.nc    
! wget https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/H_wHFacC.mat
# Out:
# --2023-04-29 20:48:04--  https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/kCluster6.npy
# Resolving get.ecmwf.int (get.ecmwf.int)... 136.156.180.32
# Connecting to get.ecmwf.int (get.ecmwf.int)|136.156.180.32|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2073728 (2.0M) [application/octet-stream]
# Saving to: ‘kCluster6.npy’
#
# kCluster6.npy       100%[===================>]   1.98M   981KB/s    in 2.1s
#
# 2023-04-29 20:48:07 (981 KB/s) - ‘kCluster6.npy’ saved [2073728/2073728]
#
# --2023-04-29 20:48:07--  https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/curlTau.npy
# Resolving get.ecmwf.int (get.ecmwf.int)... 136.156.180.32
# Connecting to get.ecmwf.int (get.ecmwf.int)|136.156.180.32|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2073728 (2.0M) [application/octet-stream]
# Saving to: ‘curlTau.npy’
#
# curlTau.npy         100%[===================>]   1.98M  1.28MB/s    in 1.5s
#
# 2023-04-29 20:48:09 (1.28 MB/s) - ‘curlTau.npy’ saved [2073728/2073728]
#
# --2023-04-29 20:48:09--  https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.1992.nc
# Resolving get.ecmwf.int (get.ecmwf.int)... 136.156.180.32
# Connecting to get.ecmwf.int (get.ecmwf.int)|136.156.180.32|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29042700 (28M) [application/x-netcdf]
# Saving to: ‘SSH.1992.nc’
#
# SSH.1992.nc         100%[===================>]  27.70M  1.32MB/s    in 21s
#
# 2023-04-29 20:48:31 (1.30 MB/s) - ‘SSH.1992.nc’ saved [29042700/29042700]
#
# --2023-04-29 20:48:31--  https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.1993.nc
# Resolving get.ecmwf.int (get.ecmwf.int)... 136.156.180.32
# Connecting to get.ecmwf.int (get.ecmwf.int)|136.156.180.32|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29042700 (28M) [application/x-netcdf]
# Saving to: ‘SSH.1993.nc’
#
# SSH.1993.nc         100%[===================>]  27.70M  1.32MB/s    in 21s
#
# 2023-04-29 20:48:53 (1.30 MB/s) - ‘SSH.1993.nc’ saved [29042700/29042700]
#
# --2023-04-29 20:48:53--  https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.1994.nc
# Resolving get.ecmwf.int (get.ecmwf.int)... 136.156.180.32
# Connecting to get.ecmwf.int (get.ecmwf.int)|136.156.180.32|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29042700 (28M) [application/x-netcdf]
# Saving to: ‘SSH.1994.nc’
#
# SSH.1994.nc         100%[===================>]  27.70M  1.32MB/s    in 21s
#
# 2023-04-29 20:49:15 (1.30 MB/s) - ‘SSH.1994.nc’ saved [29042700/29042700]
#
# --2023-04-29 20:49:15--  https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.1995.nc
# Resolving get.ecmwf.int (get.ecmwf.int)... 136.156.180.32
# Connecting to get.ecmwf.int (get.ecmwf.int)|136.156.180.32|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29042700 (28M) [application/x-netcdf]
# Saving to: ‘SSH.1995.nc’
#
# SSH.1995.nc         100%[===================>]  27.70M  1.32MB/s    in 21s
#
# 2023-04-29 20:49:36 (1.30 MB/s) - ‘SSH.1995.nc’ saved [29042700/29042700]
#
# --2023-04-29 20:49:37--  https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.1996.nc
# Resolving get.ecmwf.int (get.ecmwf.int)... 136.156.180.32
# Connecting to get.ecmwf.int (get.ecmwf.int)|136.156.180.32|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29042700 (28M) [application/x-netcdf]
# Saving to: ‘SSH.1996.nc’
#
# SSH.1996.nc         100%[===================>]  27.70M  1.31MB/s    in 21s
#
# 2023-04-29 20:49:58 (1.29 MB/s) - ‘SSH.1996.nc’ saved [29042700/29042700]
#
# --2023-04-29 20:49:59--  https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.1997.nc
# Resolving get.ecmwf.int (get.ecmwf.int)... 136.156.180.32
# Connecting to get.ecmwf.int (get.ecmwf.int)|136.156.180.32|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29042700 (28M) [application/x-netcdf]
# Saving to: ‘SSH.1997.nc’
#
# SSH.1997.nc         100%[===================>]  27.70M  1.32MB/s    in 21s
#
# 2023-04-29 20:50:20 (1.30 MB/s) - ‘SSH.1997.nc’ saved [29042700/29042700]
#
# --2023-04-29 20:50:20--  https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.1998.nc
# Resolving get.ecmwf.int (get.ecmwf.int)... 136.156.180.32
# Connecting to get.ecmwf.int (get.ecmwf.int)|136.156.180.32|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29042700 (28M) [application/x-netcdf]
# Saving to: ‘SSH.1998.nc’
#
# SSH.1998.nc         100%[===================>]  27.70M  1.31MB/s    in 22s
#
# 2023-04-29 20:50:42 (1.29 MB/s) - ‘SSH.1998.nc’ saved [29042700/29042700]
#
# --2023-04-29 20:50:42--  https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.1999.nc
# Resolving get.ecmwf.int (get.ecmwf.int)... 136.156.180.32
# Connecting to get.ecmwf.int (get.ecmwf.int)|136.156.180.32|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29042700 (28M) [application/x-netcdf]
# Saving to: ‘SSH.1999.nc’
#
# SSH.1999.nc         100%[===================>]  27.70M  1.31MB/s    in 22s
#
# 2023-04-29 20:51:04 (1.29 MB/s) - ‘SSH.1999.nc’ saved [29042700/29042700]
#
# --2023-04-29 20:51:04--  https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.2000.nc
# Resolving get.ecmwf.int (get.ecmwf.int)... 136.156.180.32
# Connecting to get.ecmwf.int (get.ecmwf.int)|136.156.180.32|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29042700 (28M) [application/x-netcdf]
# Saving to: ‘SSH.2000.nc’
#
# SSH.2000.nc         100%[===================>]  27.70M  1.30MB/s    in 22s
#
# 2023-04-29 20:51:27 (1.28 MB/s) - ‘SSH.2000.nc’ saved [29042700/29042700]
#
# --2023-04-29 20:51:27--  https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.2001.nc
# Resolving get.ecmwf.int (get.ecmwf.int)... 136.156.180.32
# Connecting to get.ecmwf.int (get.ecmwf.int)|136.156.180.32|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29042704 (28M) [application/x-netcdf]
# Saving to: ‘SSH.2001.nc’
#
# SSH.2001.nc         100%[===================>]  27.70M  1.32MB/s    in 21s
#
# 2023-04-29 20:51:48 (1.30 MB/s) - ‘SSH.2001.nc’ saved [29042704/29042704]
#
# --2023-04-29 20:51:48--  https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.2002.nc
# Resolving get.ecmwf.int (get.ecmwf.int)... 136.156.180.32
# Connecting to get.ecmwf.int (get.ecmwf.int)|136.156.180.32|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29042704 (28M) [application/x-netcdf]
# Saving to: ‘SSH.2002.nc’
#
# SSH.2002.nc         100%[===================>]  27.70M  1.32MB/s    in 21s
#
# 2023-04-29 20:52:10 (1.30 MB/s) - ‘SSH.2002.nc’ saved [29042704/29042704]
#
# --2023-04-29 20:52:10--  https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.2003.nc
# Resolving get.ecmwf.int (get.ecmwf.int)... 136.156.180.32
# Connecting to get.ecmwf.int (get.ecmwf.int)|136.156.180.32|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29042704 (28M) [application/x-netcdf]
# Saving to: ‘SSH.2003.nc’
#
# SSH.2003.nc         100%[===================>]  27.70M  1.32MB/s    in 21s
#
# 2023-04-29 20:52:32 (1.30 MB/s) - ‘SSH.2003.nc’ saved [29042704/29042704]
#
# --2023-04-29 20:52:32--  https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.2004.nc
# Resolving get.ecmwf.int (get.ecmwf.int)... 136.156.180.32
# Connecting to get.ecmwf.int (get.ecmwf.int)|136.156.180.32|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29042704 (28M) [application/x-netcdf]
# Saving to: ‘SSH.2004.nc’
#
# SSH.2004.nc         100%[===================>]  27.70M  1.32MB/s    in 21s
#
# 2023-04-29 20:52:54 (1.30 MB/s) - ‘SSH.2004.nc’ saved [29042704/29042704]
#
# --2023-04-29 20:52:54--  https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.2005.nc
# Resolving get.ecmwf.int (get.ecmwf.int)... 136.156.180.32
# Connecting to get.ecmwf.int (get.ecmwf.int)|136.156.180.32|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29042704 (28M) [application/x-netcdf]
# Saving to: ‘SSH.2005.nc’
#
# SSH.2005.nc         100%[===================>]  27.70M  1.31MB/s    in 22s
#
# 2023-04-29 20:53:16 (1.29 MB/s) - ‘SSH.2005.nc’ saved [29042704/29042704]
#
# --2023-04-29 20:53:16--  https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.2006.nc
# Resolving get.ecmwf.int (get.ecmwf.int)... 136.156.180.32
# Connecting to get.ecmwf.int (get.ecmwf.int)|136.156.180.32|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29042704 (28M) [application/x-netcdf]
# Saving to: ‘SSH.2006.nc’
#
# SSH.2006.nc         100%[===================>]  27.70M  1.32MB/s    in 21s
#
# 2023-04-29 20:53:38 (1.30 MB/s) - ‘SSH.2006.nc’ saved [29042704/29042704]
#
# --2023-04-29 20:53:38--  https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.2007.nc
# Resolving get.ecmwf.int (get.ecmwf.int)... 136.156.180.32
# Connecting to get.ecmwf.int (get.ecmwf.int)|136.156.180.32|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29042704 (28M) [application/x-netcdf]
# Saving to: ‘SSH.2007.nc’
#
# SSH.2007.nc         100%[===================>]  27.70M  1.33MB/s    in 21s
#
# 2023-04-29 20:54:00 (1.30 MB/s) - ‘SSH.2007.nc’ saved [29042704/29042704]
#
# --2023-04-29 20:54:00--  https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.2008.nc
# Resolving get.ecmwf.int (get.ecmwf.int)... 136.156.180.32
# Connecting to get.ecmwf.int (get.ecmwf.int)|136.156.180.32|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29042704 (28M) [application/x-netcdf]
# Saving to: ‘SSH.2008.nc’
#
# SSH.2008.nc         100%[===================>]  27.70M  1.31MB/s    in 21s
#
# 2023-04-29 20:54:22 (1.29 MB/s) - ‘SSH.2008.nc’ saved [29042704/29042704]
#
# --2023-04-29 20:54:22--  https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.2009.nc
# Resolving get.ecmwf.int (get.ecmwf.int)... 136.156.180.32
# Connecting to get.ecmwf.int (get.ecmwf.int)|136.156.180.32|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29042704 (28M) [application/x-netcdf]
# Saving to: ‘SSH.2009.nc’
#
# SSH.2009.nc         100%[===================>]  27.70M  1.31MB/s    in 21s
#
# 2023-04-29 20:54:44 (1.29 MB/s) - ‘SSH.2009.nc’ saved [29042704/29042704]
#
# --2023-04-29 20:54:44--  https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.2010.nc
# Resolving get.ecmwf.int (get.ecmwf.int)... 136.156.180.32
# Connecting to get.ecmwf.int (get.ecmwf.int)|136.156.180.32|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29042704 (28M) [application/x-netcdf]
# Saving to: ‘SSH.2010.nc’
#
# SSH.2010.nc         100%[===================>]  27.70M  1.33MB/s    in 21s
#
# 2023-04-29 20:55:06 (1.30 MB/s) - ‘SSH.2010.nc’ saved [29042704/29042704]
#
# --2023-04-29 20:55:06--  https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/SSHdata/SSH.2011.nc
# Resolving get.ecmwf.int (get.ecmwf.int)... 136.156.180.32
# Connecting to get.ecmwf.int (get.ecmwf.int)|136.156.180.32|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29042704 (28M) [application/x-netcdf]
# Saving to: ‘SSH.2011.nc’
#
# SSH.2011.nc         100%[===================>]  27.70M  1.32MB/s    in 21s
#
# 2023-04-29 20:55:28 (1.30 MB/s) - ‘SSH.2011.nc’ saved [29042704/29042704]
#
# --2023-04-29 20:55:28--  https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_2/uncertainty/H_wHFacC.mat
# Resolving get.ecmwf.int (get.ecmwf.int)... 136.156.180.32
# Connecting to get.ecmwf.int (get.ecmwf.int)|136.156.180.32|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1308373 (1.2M) [application/x-matlab-data]
# Saving to: ‘H_wHFacC.mat’
#
# H_wHFacC.mat        100%[===================>]   1.25M  1.18MB/s    in 1.1s
#
# 2023-04-29 20:55:29 (1.18 MB/s) - ‘H_wHFacC.mat’ saved [1308373/1308373]

# %%
print(np.load('curlTau.npy'))
# Out:
# [[            nan             nan             nan ... -1.50804074e-11
#   -2.40229606e-11 -1.33861875e-11]
#  [            nan             nan             nan ... -1.38740423e-11
#   -2.33721971e-11 -1.32861630e-11]
#  [            nan             nan             nan ... -1.26829094e-11
#   -2.27163128e-11 -1.31878838e-11]
#  ...
#  [            nan             nan             nan ... -1.75898502e-11
#   -2.59515534e-11 -1.36808540e-11]
#  [            nan             nan             nan ... -1.70483291e-11
#   -2.53148197e-11 -1.35834491e-11]
#  [            nan             nan             nan ... -1.62937674e-11
#   -2.46727400e-11 -1.34843067e-11]]

# %%
print(np.transpose(np.load('curlTau.npy')))
# Out:
# [[            nan             nan             nan ...             nan
#               nan             nan]
#  [            nan             nan             nan ...             nan
#               nan             nan]
#  [            nan             nan             nan ...             nan
#               nan             nan]
#  ...
#  [-1.50804074e-11 -1.38740423e-11 -1.26829094e-11 ... -1.75898502e-11
#   -1.70483291e-11 -1.62937674e-11]
#  [-2.40229606e-11 -2.33721971e-11 -2.27163128e-11 ... -2.59515534e-11
#   -2.53148197e-11 -2.46727400e-11]
#  [-1.33861875e-11 -1.32861630e-11 -1.31878838e-11 ... -1.36808540e-11
#   -1.35834491e-11 -1.34843067e-11]]

# %%
print(np.load('curlTau.npy').shape)
print(np.transpose(np.load('curlTau.npy')).shape)
# Out:
# (720, 360)
# (360, 720)

# %%
wind_stress_curl = np.transpose(np.load('curlTau.npy'))
monthly_ssh = xr.open_mfdataset('SSH.*.nc', combine='by_coords')
SSH20mean = monthly_ssh['SSH'].mean(axis=0).values  # 20 years mean of sea surface height
bathymetry = np.transpose(loadmat('H_wHFacC.mat')['val'])

# %%
## Load in ocean regimes labels as target data. These ocean regimes were determined in Sonnewald et al. 2019
ecco_label = np.transpose(np.load('kCluster6.npy'))

# replace land pixels by NaNs
ecco_label[ecco_label==-1] = np.nan

# %%
## Calculate the SSH gradients, bathymetry gradients and coriolis

lonRoll = np.roll(monthly_ssh['lat'].values, axis=0, shift=-1)
Londiff = lonRoll - monthly_ssh['lat'].values  # equivalent to doing x_{i} - x_{i-1}

lat = monthly_ssh['lat'].values
latDiff=1.111774765625000e+05
latY=np.gradient(lat, axis=0)*latDiff
lonX=np.abs(np.cos(lat*np.pi/180))*latDiff*Londiff

##coriolis 
Omega=7.2921e-5 # coriolis parameter
f = (2*Omega*np.sin(lat*np.pi/180))

def grad(d,y,x):
    grady=np.gradient(d, axis=0)/y
    gradx=np.gradient(d, axis=1)/x
    return grady, gradx

gradSSH_y, gradSSH_x = grad(SSH20mean,latY,lonX)
gradBathm_y, gradBathm_x = grad(bathymetry,latY,lonX)

# %%
## Plot data

plt.figure(figsize=(20,15))

plt.subplot(4,2,1)
plt.imshow(np.flipud(wind_stress_curl), cmap='seismic')
plt.colorbar(shrink=0.5)
plt.clim(-1e-9,1e-9)
plt.title('Wind stress curl')

plt.subplot(4,2,2)
plt.imshow(np.flipud(SSH20mean), cmap='seismic')
plt.colorbar(shrink=0.5)
plt.title('Mean sea surface height')

plt.subplot(4,2,3)
plt.imshow(np.flipud(gradSSH_x), cmap='seismic')
plt.colorbar(shrink=0.5)
plt.title('gradSSH_x')

plt.subplot(4,2,4)
plt.imshow(np.flipud(gradSSH_y), cmap='seismic')
plt.colorbar(shrink=0.5)
plt.title('gradSSH_y')

plt.subplot(4,2,5)
plt.imshow(np.flipud(bathymetry), cmap='seismic')
plt.colorbar(shrink=0.5)
plt.title('Bathymetry')

plt.subplot(4,2,6)
plt.imshow(np.flipud(gradBathm_x), cmap='seismic')
plt.colorbar(shrink=0.5)
plt.title('gradBathm_x')

plt.subplot(4,2,7)
plt.imshow(np.flipud(gradBathm_y), cmap='seismic')
plt.colorbar(shrink=0.5)
plt.title('gradBathm_y')

plt.subplot(4,2,8)
plt.imshow(np.flipud(f), cmap='seismic')
plt.colorbar(shrink=0.5)
plt.title('Coriolis')

plt.show()

# %%
## Mask land pixels and other noisy locations
missingdataindex = np.isnan(wind_stress_curl*SSH20mean*gradSSH_x*gradSSH_y*bathymetry*gradBathm_x*gradBathm_y)

## Training data is ocean dataset excluding the Atlantic Ocean
maskTraining = (~missingdataindex).copy()
maskTraining[:,200:400]=False # mask out the Longitude 200 to 400 for the training set 

## Test dataset is Atlantic Ocean dataset
maskTest = (~missingdataindex).copy()
maskTest[:,list(range(200))+list(range(400,720))]=False # mask out Longtitude 0 to 200 and 400 to 720

# %%
## Set up training and test datasets

TotalDataset = np.stack((wind_stress_curl[~missingdataindex],
                         SSH20mean[~missingdataindex],
                         gradSSH_x[~missingdataindex],
                         gradSSH_y[~missingdataindex],
                         bathymetry[~missingdataindex],
                         gradBathm_x[~missingdataindex],
                         gradBathm_y[~missingdataindex],
                         f[~missingdataindex]),1)

TrainDataset = np.stack((wind_stress_curl[maskTraining],
                         SSH20mean[maskTraining],
                         gradSSH_x[maskTraining],
                         gradSSH_y[maskTraining],
                         bathymetry[maskTraining],
                         gradBathm_x[maskTraining],
                         gradBathm_y[maskTraining],
                         f[maskTraining]),1)

TestDataset = np.stack((wind_stress_curl[maskTest],
                         SSH20mean[maskTest],
                         gradSSH_x[maskTest],
                         gradSSH_y[maskTest],
                         bathymetry[maskTest],
                         gradBathm_x[maskTest],
                         gradBathm_y[maskTest],
                       f[maskTest]),1)

print(TotalDataset.shape, TrainDataset.shape, TestDataset.shape)

train_label = ecco_label[maskTraining]
test_label = ecco_label[maskTest]
print(train_label.shape, test_label.shape)
# Out:
# (149587, 8) (109259, 8) (40328, 8)
# (109259,) (40328,)

# %%
## Scale the data

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(TrainDataset)
scaler.mean_,scaler.scale_

X_train_scaled = scaler.transform(TrainDataset)
X_test_scaled = scaler.transform(TestDataset)

# %% [markdown]
# # Training the Bayesian Neural Network (BNN)

# %% [markdown]
# To use a BNN we must import both `tensorflow` and `tensorflow_probability`

# %%
import tensorflow as tf
import tensorflow_probability as tfp

tfd = tfp.distributions
tfpl = tfp.layers

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import RMSprop

# convert target labels to appropriate data type for tensorflow
Y_train = tf.keras.utils.to_categorical(train_label)
Y_test = tf.keras.utils.to_categorical(test_label)

# %% [markdown]
# # Exercise 1
#
# The first task is to build a deterministic network to predict the ocean regimes. Evaluate the accuracy of your model.
#
# *Hint: The data is shaped for a gridpoint-by-gridpoint approach so Dense layers are appropriate here. The target data is categorical so the last layer should have a SoftMax activation.*

# %% [markdown]
# #### <span style='color:blue'>Use the hyperbolic tangent (tanh) activation function in the first few layers. Set `units = 6` in the last layer because we have 6 regimes in the target labels.</span>

# %%
#Solution
def deterministic_model():
    model = Sequential([
      Dense(input_shape = (8,), units =24,
                            activation = tf.keras.activations.tanh),
      Dense(units =24, activation = tf.keras.activations.tanh),
      Dense(units =16, activation = tf.keras.activations.tanh),
      Dense(units =16, activation = tf.keras.activations.tanh),
      Dense(units =6, activation = tf.keras.activations.softmax),                
      ])
    return model

# %%
# Compile and fit the deterministic model
det_model = deterministic_model()
det_model.summary()
det_model.compile(loss = 'categorical_crossentropy', metrics = ['categorical_accuracy'],
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.01))
det_model.fit(X_train_scaled, Y_train,
                    batch_size=32,
                    epochs=10,
                    verbose=1,
                    validation_split = 0.2, shuffle = True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 24)                216
#
#  dense_1 (Dense)             (None, 24)                600
#
#  dense_2 (Dense)             (None, 16)                400
#
#  dense_3 (Dense)             (None, 16)                272
#
#  dense_4 (Dense)             (None, 6)                 102
#
# =================================================================
# Total params: 1,590
# Trainable params: 1,590
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2732/2732 [==============================] - 20s 5ms/step - loss: 0.3928 - categorical_accuracy: 0.8600 - val_loss: 0.6797 - val_categorical_accuracy: 0.7711
# Epoch 2/10
# 2732/2732 [==============================] - 14s 5ms/step - loss: 0.3180 - categorical_accuracy: 0.8847 - val_loss: 0.5308 - val_categorical_accuracy: 0.8353
# Epoch 3/10
# 2732/2732 [==============================] - 15s 5ms/step - loss: 0.3033 - categorical_accuracy: 0.8879 - val_loss: 0.5153 - val_categorical_accuracy: 0.8162
# Epoch 4/10
# 2732/2732 [==============================] - 14s 5ms/step - loss: 0.2923 - categorical_accuracy: 0.8908 - val_loss: 0.5707 - val_categorical_accuracy: 0.8016
# Epoch 5/10
# 2732/2732 [==============================] - 14s 5ms/step - loss: 0.2899 - categorical_accuracy: 0.8904 - val_loss: 0.6603 - val_categorical_accuracy: 0.7430
# Epoch 6/10
# 2732/2732 [==============================] - 16s 6ms/step - loss: 0.2862 - categorical_accuracy: 0.8921 - val_loss: 0.6463 - val_categorical_accuracy: 0.8289
# Epoch 7/10
# 2732/2732 [==============================] - 16s 6ms/step - loss: 0.2868 - categorical_accuracy: 0.8915 - val_loss: 0.6180 - val_categorical_accuracy: 0.7669
# Epoch 8/10
# 2732/2732 [==============================] - 14s 5ms/step - loss: 0.2808 - categorical_accuracy: 0.8942 - val_loss: 0.7023 - val_categorical_accuracy: 0.7954
# Epoch 9/10
# 2732/2732 [==============================] - 13s 5ms/step - loss: 0.2911 - categorical_accuracy: 0.8923 - val_loss: 0.6148 - val_categorical_accuracy: 0.8308
# Epoch 10/10
# 2732/2732 [==============================] - 14s 5ms/step - loss: 0.2825 - categorical_accuracy: 0.8952 - val_loss: 0.6335 - val_categorical_accuracy: 0.7636

# %%
# Evaluate the accuracy of this deterministic model

print(det_model.evaluate(X_train_scaled, Y_train))
print(det_model.evaluate(X_test_scaled, Y_test))
# Out:
# 3415/3415 [==============================] - 10s 3ms/step - loss: 0.3432 - categorical_accuracy: 0.8706
# [0.3431701958179474, 0.8705827593803406]
# 1261/1261 [==============================] - 3s 3ms/step - loss: 0.5839 - categorical_accuracy: 0.7920
# [0.583927571773529, 0.7919807434082031]

# %% [markdown]
# # Exercise 2
#
# Change your deterministic neural network from Exercise 1 so that it predicts a distribution as an output, quantifying the aleatoric uncertainty. Evaluate the accuracy of your model.
#
#
# *Hint: You should use the OneHotCategorical Layer from Tensorflow probability because this means that the output of the network is a distribution.*

# %%
#Solution

def probabilistic_model():
    model = Sequential([
      Dense(input_shape = (8,), units =24,
                            activation = tf.keras.activations.tanh),
      Dense(units =24, activation = tf.keras.activations.tanh),
      Dense(units =16, activation = tf.keras.activations.tanh),
      Dense(units =16, activation = tf.keras.activations.tanh),
      Dense(units =6, activation = None),
      tfpl.OneHotCategorical(6)])
    return model

# %%
prob_model = probabilistic_model()

prob_model.summary()

# define the negative log-likelihood function
def nll(y_true, y_pred):
    return -y_pred.log_prob(y_true)

prob_model.compile(loss=nll,
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
              metrics=['accuracy'])

prob_model.fit(X_train_scaled, Y_train,
                    batch_size=32,
                    epochs=20,
                    verbose=1,
                    validation_split = 0.2, shuffle = True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 24)                216
#
#  dense_6 (Dense)             (None, 24)                600
#
#  dense_7 (Dense)             (None, 16)                400
#
#  dense_8 (Dense)             (None, 16)                272
#
#  dense_9 (Dense)             (None, 6)                 102
#
#  one_hot_categorical (OneHot  ((None, 6),              0
#  Categorical)                 (None, 6))
#
# =================================================================
# Total params: 1,590
# Trainable params: 1,590
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2732/2732 [==============================] - 17s 6ms/step - loss: 0.3833 - accuracy: 0.7966 - val_loss: 0.5726 - val_accuracy: 0.7272
# Epoch 2/20
# 2732/2732 [==============================] - 13s 5ms/step - loss: 0.3204 - accuracy: 0.8313 - val_loss: 0.5882 - val_accuracy: 0.6868
# Epoch 3/20
# 2732/2732 [==============================] - 15s 5ms/step - loss: 0.3102 - accuracy: 0.8371 - val_loss: 0.5253 - val_accuracy: 0.7573
# Epoch 4/20
# 2732/2732 [==============================] - 15s 5ms/step - loss: 0.3022 - accuracy: 0.8398 - val_loss: 0.7199 - val_accuracy: 0.6717
# Epoch 5/20
# 2732/2732 [==============================] - 15s 6ms/step - loss: 0.3027 - accuracy: 0.8424 - val_loss: 0.5779 - val_accuracy: 0.7141
# Epoch 6/20
# 2732/2732 [==============================] - 15s 5ms/step - loss: 0.3016 - accuracy: 0.8431 - val_loss: 0.5332 - val_accuracy: 0.7462
# Epoch 7/20
# 2732/2732 [==============================] - 15s 5ms/step - loss: 0.3029 - accuracy: 0.8411 - val_loss: 0.5674 - val_accuracy: 0.7304
# Epoch 8/20
# 2732/2732 [==============================] - 15s 5ms/step - loss: 0.2994 - accuracy: 0.8451 - val_loss: 0.6508 - val_accuracy: 0.7127
# Epoch 9/20
# 2732/2732 [==============================] - 15s 6ms/step - loss: 0.3002 - accuracy: 0.8436 - val_loss: 0.7828 - val_accuracy: 0.6765
# Epoch 10/20
# 2732/2732 [==============================] - 15s 5ms/step - loss: 0.3020 - accuracy: 0.8422 - val_loss: 0.5829 - val_accuracy: 0.7542
# Epoch 11/20
# 2732/2732 [==============================] - 14s 5ms/step - loss: 0.3029 - accuracy: 0.8430 - val_loss: 0.6088 - val_accuracy: 0.7086
# Epoch 12/20
# 2732/2732 [==============================] - 15s 6ms/step - loss: 0.3009 - accuracy: 0.8422 - val_loss: 0.6373 - val_accuracy: 0.7370
# Epoch 13/20
# 2732/2732 [==============================] - 15s 6ms/step - loss: 0.3086 - accuracy: 0.8404 - val_loss: 0.6382 - val_accuracy: 0.7024
# Epoch 14/20
# 2732/2732 [==============================] - 15s 5ms/step - loss: 0.2965 - accuracy: 0.8459 - val_loss: 0.5868 - val_accuracy: 0.7302
# Epoch 15/20
# 2732/2732 [==============================] - 14s 5ms/step - loss: 0.3031 - accuracy: 0.8410 - val_loss: 0.6049 - val_accuracy: 0.7543
# Epoch 16/20
# 2732/2732 [==============================] - 14s 5ms/step - loss: 0.3084 - accuracy: 0.8391 - val_loss: 0.5466 - val_accuracy: 0.7673
# Epoch 17/20
# 2732/2732 [==============================] - 16s 6ms/step - loss: 0.3095 - accuracy: 0.8392 - val_loss: 0.6645 - val_accuracy: 0.6938
# Epoch 18/20
# 2732/2732 [==============================] - 14s 5ms/step - loss: 0.3096 - accuracy: 0.8375 - val_loss: 0.7271 - val_accuracy: 0.6837
# Epoch 19/20
# 2732/2732 [==============================] - 14s 5ms/step - loss: 0.3140 - accuracy: 0.8377 - val_loss: 0.5074 - val_accuracy: 0.7759
# Epoch 20/20
# 2732/2732 [==============================] - 14s 5ms/step - loss: 0.3062 - accuracy: 0.8427 - val_loss: 0.5676 - val_accuracy: 0.7525

# %%
## Example output
prob_model(X_test_scaled[0:1]).mean().numpy()
# Out:
# array([[7.5043123e-03, 1.3771650e-01, 1.3605908e-04, 2.0694478e-01,
#         1.8407303e-06, 6.4769650e-01]], dtype=float32)

# %%
# Evaluate the accuracy of this first Bayesian model

print(prob_model.evaluate(X_train_scaled, Y_train))
print(prob_model.evaluate(X_test_scaled, Y_test))
# Out:
# 3415/3415 [==============================] - 11s 3ms/step - loss: 0.3488 - accuracy: 0.8269
# [0.34880775213241577, 0.8268792629241943]
# 1261/1261 [==============================] - 4s 3ms/step - loss: 0.5952 - accuracy: 0.7391
# [0.5952227115631104, 0.7390894889831543]

# %% [markdown]
# # Exercise 3
#
# Change your neural network from Exercise 2 so that it quantifies epistemic uncertainty as well as aleatoric uncertainty. Evaluate the accuracy of your model. The accuracy will almost definitely be less than that from the deterministic model, but with the added benefit that you now have uncertainty information.
#
# *Hint: In BNNs, the parameters (weights and biases) are distributions rather than deterministic. Standard practice with tensorflow probability is to determine this distributions using variational inference. Therefore we must define a fixed prior for each of the weights and the general shape for the posterior. Dense layers in a deterministic network are replaced with DenseVariational layers in a BNN. Note that you also have to rescale the KL divergence error so that the arguments for your DenseVariational layer should include the following arguments:*
#
# ```
# kl_weight = 1/X_train_scaled.shape[0], # have to rescale the kl_error
# kl_use_exact=True # use if have analytic form of prior and posterior - may error in which case change to False
# ```

# %%
#Solution

# Define the prior weight distribution -- all N(0, 1) -- and not trainable
def prior(kernel_size, bias_size, dtype = None):
    n = kernel_size + bias_size
    prior_model = Sequential([
                            tfpl.DistributionLambda(
                                lambda t: tfd.MultivariateNormalDiag(loc = tf.zeros(n), scale_diag = tf.ones(n))
                            )
    ]) # normal distribution for each weight in the layer
    return prior_model

# Define variational posterior weight distribution -- multivariate Gaussian

def posterior(kernel_size, bias_size, dtype = None):
    n = kernel_size + bias_size
    posterior_model = Sequential([
                tfpl.VariableLayer(2*n, dtype=dtype),
                tfpl.DistributionLambda (
        lambda t: tfd.MultivariateNormalDiag(loc = t[..., :n], scale_diag = tf.math.exp(t[..., n:])))
    ]) # define posterior for each weight in the layer
    return posterior_model

def bnn():
  model = Sequential([
    tfpl.DenseVariational(input_shape = (8,), units =24,
                          activation = tf.keras.activations.tanh,
                          make_prior_fn=prior,
                          make_posterior_fn=posterior,
                          kl_weight = 1/X_train_scaled.shape[0], # have to rescale the kl_error
                          kl_use_exact=True # use if have analytic form of prior and posterior - may error in which case change to False
                          ),
    tfpl.DenseVariational(units =24,
                          activation = tf.keras.activations.tanh,
                          make_prior_fn=prior,
                          make_posterior_fn=posterior,
                          kl_weight = 1/X_train_scaled.shape[0], # have to rescale the kl_error
                          kl_use_exact=True # use if have analytic form of prior and posterior - may error in which case change to False
                          ),
    tfpl.DenseVariational(units =16,
                          activation = tf.keras.activations.tanh,
                          make_prior_fn=prior,
                          make_posterior_fn=posterior,
                          kl_weight = 1/X_train_scaled.shape[0], # have to rescale the kl_error
                          kl_use_exact=True # use if have analytic form of prior and posterior - may error in which case change to False
                          ),
    tfpl.DenseVariational(units =16,
                          activation = tf.keras.activations.tanh,
                          make_prior_fn=prior,
                          make_posterior_fn=posterior,
                          kl_weight = 1/X_train_scaled.shape[0], # have to rescale the kl_error
                          kl_use_exact=True # use if have analytic form of prior and posterior - may error in which case change to False
                          ),                    
    tfpl.DenseVariational(units =6,
                          make_prior_fn=prior,
                          make_posterior_fn=posterior,
                          kl_weight = 1/X_train_scaled.shape[0], # have to rescale the kl_error
                          kl_use_exact=True # use if have analytic form of prior and posterior - may error in which case change to False
                          ),
   tfpl.OneHotCategorical(6)])
  return model

# %%
bnn_model = bnn()

def nll(y_true, y_pred):
    return -y_pred.log_prob(y_true)

bnn_model.compile(loss=nll,
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
              metrics=['accuracy'])

# add callbacks to save best weights
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    'bnn_weights.h5', monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch')

# and to reduce the learning rate if the error does not improve after 15 epochs
reduce_lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
            monitor = 'val_loss',
            patience=15,
            factor=0.25,
            verbose=1)

# fit model
bnn_model.fit(X_train_scaled, Y_train,
                    batch_size=32,
                    epochs=100,
                    verbose=1,
                    validation_split = 0.2, shuffle = True,
                    callbacks = [checkpoint_callback, reduce_lr_callback])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow_probability/python/distributions/distribution.py:342: calling MultivariateNormalDiag.__init__ (from tensorflow_probability.python.distributions.mvn_diag) with scale_identity_multiplier is deprecated and will be removed after 2020-01-01.
# Instructions for updating:
# `scale_identity_multiplier` is deprecated; please combine it into `scale_diag` directly instead.
# Epoch 1/100
# 2728/2732 [============================>.] - ETA: 0s - loss: 2.0691 - accuracy: 0.2103
# Epoch 1: val_loss improved from inf to 1.65215, saving model to bnn_weights.h5
# 2732/2732 [==============================] - 31s 8ms/step - loss: 2.0686 - accuracy: 0.2103 - val_loss: 1.6521 - val_accuracy: 0.2289 - lr: 0.0100
# Epoch 2/100
# 2731/2732 [============================>.] - ETA: 0s - loss: 1.6893 - accuracy: 0.2133
# Epoch 2: val_loss improved from 1.65215 to 1.60720, saving model to bnn_weights.h5
# 2732/2732 [==============================] - 18s 7ms/step - loss: 1.6894 - accuracy: 0.2133 - val_loss: 1.6072 - val_accuracy: 0.2290 - lr: 0.0100
# Epoch 3/100
# 2729/2732 [============================>.] - ETA: 0s - loss: 1.2980 - accuracy: 0.3360
# Epoch 3: val_loss improved from 1.60720 to 1.40448, saving model to bnn_weights.h5
# 2732/2732 [==============================] - 19s 7ms/step - loss: 1.2977 - accuracy: 0.3361 - val_loss: 1.4045 - val_accuracy: 0.3782 - lr: 0.0100
# Epoch 4/100
# 2732/2732 [==============================] - ETA: 0s - loss: 0.8022 - accuracy: 0.5745
# Epoch 4: val_loss improved from 1.40448 to 1.20879, saving model to bnn_weights.h5
# 2732/2732 [==============================] - 18s 7ms/step - loss: 0.8022 - accuracy: 0.5745 - val_loss: 1.2088 - val_accuracy: 0.5099 - lr: 0.0100
# Epoch 5/100
# 2726/2732 [============================>.] - ETA: 0s - loss: 0.6779 - accuracy: 0.6413
# Epoch 5: val_loss improved from 1.20879 to 0.92402, saving model to bnn_weights.h5
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.6778 - accuracy: 0.6414 - val_loss: 0.9240 - val_accuracy: 0.5956 - lr: 0.0100
# Epoch 6/100
# 2732/2732 [==============================] - ETA: 0s - loss: 0.6339 - accuracy: 0.6638
# Epoch 6: val_loss improved from 0.92402 to 0.92384, saving model to bnn_weights.h5
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.6339 - accuracy: 0.6638 - val_loss: 0.9238 - val_accuracy: 0.6317 - lr: 0.0100
# Epoch 7/100
# 2729/2732 [============================>.] - ETA: 0s - loss: 0.5688 - accuracy: 0.7140
# Epoch 7: val_loss improved from 0.92384 to 0.79201, saving model to bnn_weights.h5
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.5689 - accuracy: 0.7140 - val_loss: 0.7920 - val_accuracy: 0.6700 - lr: 0.0100
# Epoch 8/100
# 2728/2732 [============================>.] - ETA: 0s - loss: 0.5167 - accuracy: 0.7509
# Epoch 8: val_loss did not improve from 0.79201
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.5169 - accuracy: 0.7508 - val_loss: 0.8293 - val_accuracy: 0.6695 - lr: 0.0100
# Epoch 9/100
# 2730/2732 [============================>.] - ETA: 0s - loss: 0.4965 - accuracy: 0.7600
# Epoch 9: val_loss did not improve from 0.79201
# 2732/2732 [==============================] - 22s 8ms/step - loss: 0.4965 - accuracy: 0.7599 - val_loss: 0.8923 - val_accuracy: 0.6808 - lr: 0.0100
# Epoch 10/100
# 2724/2732 [============================>.] - ETA: 0s - loss: 0.4807 - accuracy: 0.7683
# Epoch 10: val_loss did not improve from 0.79201
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.4805 - accuracy: 0.7684 - val_loss: 0.9714 - val_accuracy: 0.6347 - lr: 0.0100
# Epoch 11/100
# 2728/2732 [============================>.] - ETA: 0s - loss: 0.4788 - accuracy: 0.7725
# Epoch 11: val_loss did not improve from 0.79201
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.4790 - accuracy: 0.7724 - val_loss: 1.0480 - val_accuracy: 0.5852 - lr: 0.0100
# Epoch 12/100
# 2724/2732 [============================>.] - ETA: 0s - loss: 0.4756 - accuracy: 0.7765
# Epoch 12: val_loss did not improve from 0.79201
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.4755 - accuracy: 0.7765 - val_loss: 0.9049 - val_accuracy: 0.6193 - lr: 0.0100
# Epoch 13/100
# 2730/2732 [============================>.] - ETA: 0s - loss: 0.4744 - accuracy: 0.7785
# Epoch 13: val_loss did not improve from 0.79201
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.4744 - accuracy: 0.7785 - val_loss: 1.0793 - val_accuracy: 0.6198 - lr: 0.0100
# Epoch 14/100
# 2727/2732 [============================>.] - ETA: 0s - loss: 0.4770 - accuracy: 0.7744
# Epoch 14: val_loss did not improve from 0.79201
# 2732/2732 [==============================] - 18s 7ms/step - loss: 0.4771 - accuracy: 0.7745 - val_loss: 0.8836 - val_accuracy: 0.6275 - lr: 0.0100
# Epoch 15/100
# 2729/2732 [============================>.] - ETA: 0s - loss: 0.4688 - accuracy: 0.7792
# Epoch 15: val_loss did not improve from 0.79201
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.4687 - accuracy: 0.7793 - val_loss: 0.8020 - val_accuracy: 0.6644 - lr: 0.0100
# Epoch 16/100
# 2731/2732 [============================>.] - ETA: 0s - loss: 0.4599 - accuracy: 0.7847
# Epoch 16: val_loss did not improve from 0.79201
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.4599 - accuracy: 0.7847 - val_loss: 0.9492 - val_accuracy: 0.5768 - lr: 0.0100
# Epoch 17/100
# 2727/2732 [============================>.] - ETA: 0s - loss: 0.4687 - accuracy: 0.7799
# Epoch 17: val_loss did not improve from 0.79201
# 2732/2732 [==============================] - 21s 8ms/step - loss: 0.4686 - accuracy: 0.7800 - val_loss: 0.8826 - val_accuracy: 0.6452 - lr: 0.0100
# Epoch 18/100
# 2729/2732 [============================>.] - ETA: 0s - loss: 0.4662 - accuracy: 0.7824
# Epoch 18: val_loss did not improve from 0.79201
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.4661 - accuracy: 0.7823 - val_loss: 0.7968 - val_accuracy: 0.6704 - lr: 0.0100
# Epoch 19/100
# 2723/2732 [============================>.] - ETA: 0s - loss: 0.4725 - accuracy: 0.7819
# Epoch 19: val_loss did not improve from 0.79201
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.4724 - accuracy: 0.7820 - val_loss: 1.0877 - val_accuracy: 0.6386 - lr: 0.0100
# Epoch 20/100
# 2726/2732 [============================>.] - ETA: 0s - loss: 0.4676 - accuracy: 0.7827
# Epoch 20: val_loss improved from 0.79201 to 0.73417, saving model to bnn_weights.h5
# 2732/2732 [==============================] - 18s 7ms/step - loss: 0.4674 - accuracy: 0.7828 - val_loss: 0.7342 - val_accuracy: 0.7085 - lr: 0.0100
# Epoch 21/100
# 2729/2732 [============================>.] - ETA: 0s - loss: 0.4762 - accuracy: 0.7726
# Epoch 21: val_loss did not improve from 0.73417
# 2732/2732 [==============================] - 20s 7ms/step - loss: 0.4761 - accuracy: 0.7726 - val_loss: 0.8474 - val_accuracy: 0.6390 - lr: 0.0100
# Epoch 22/100
# 2731/2732 [============================>.] - ETA: 0s - loss: 0.4849 - accuracy: 0.7707
# Epoch 22: val_loss did not improve from 0.73417
# 2732/2732 [==============================] - 18s 7ms/step - loss: 0.4849 - accuracy: 0.7707 - val_loss: 0.8176 - val_accuracy: 0.6728 - lr: 0.0100
# Epoch 23/100
# 2727/2732 [============================>.] - ETA: 0s - loss: 0.4920 - accuracy: 0.7674
# Epoch 23: val_loss did not improve from 0.73417
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.4919 - accuracy: 0.7675 - val_loss: 0.9029 - val_accuracy: 0.6779 - lr: 0.0100
# Epoch 24/100
# 2731/2732 [============================>.] - ETA: 0s - loss: 0.4770 - accuracy: 0.7815
# Epoch 24: val_loss did not improve from 0.73417
# 2732/2732 [==============================] - 18s 7ms/step - loss: 0.4769 - accuracy: 0.7815 - val_loss: 0.8279 - val_accuracy: 0.6470 - lr: 0.0100
# Epoch 25/100
# 2728/2732 [============================>.] - ETA: 0s - loss: 0.4762 - accuracy: 0.7771
# Epoch 25: val_loss did not improve from 0.73417
# 2732/2732 [==============================] - 20s 7ms/step - loss: 0.4762 - accuracy: 0.7770 - val_loss: 0.8306 - val_accuracy: 0.6957 - lr: 0.0100
# Epoch 26/100
# 2731/2732 [============================>.] - ETA: 0s - loss: 0.4658 - accuracy: 0.7829
# Epoch 26: val_loss did not improve from 0.73417
# 2732/2732 [==============================] - 20s 7ms/step - loss: 0.4658 - accuracy: 0.7829 - val_loss: 0.8942 - val_accuracy: 0.6987 - lr: 0.0100
# Epoch 27/100
# 2730/2732 [============================>.] - ETA: 0s - loss: 0.4721 - accuracy: 0.7780
# Epoch 27: val_loss did not improve from 0.73417
# 2732/2732 [==============================] - 20s 7ms/step - loss: 0.4722 - accuracy: 0.7780 - val_loss: 0.7445 - val_accuracy: 0.7290 - lr: 0.0100
# Epoch 28/100
# 2732/2732 [==============================] - ETA: 0s - loss: 0.4797 - accuracy: 0.7705
# Epoch 28: val_loss did not improve from 0.73417
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.4797 - accuracy: 0.7705 - val_loss: 0.8716 - val_accuracy: 0.6481 - lr: 0.0100
# Epoch 29/100
# 2731/2732 [============================>.] - ETA: 0s - loss: 0.4669 - accuracy: 0.7797
# Epoch 29: val_loss did not improve from 0.73417
# 2732/2732 [==============================] - 20s 7ms/step - loss: 0.4669 - accuracy: 0.7797 - val_loss: 0.8222 - val_accuracy: 0.7031 - lr: 0.0100
# Epoch 30/100
# 2729/2732 [============================>.] - ETA: 0s - loss: 0.4835 - accuracy: 0.7777
# Epoch 30: val_loss improved from 0.73417 to 0.72815, saving model to bnn_weights.h5
# 2732/2732 [==============================] - 18s 7ms/step - loss: 0.4835 - accuracy: 0.7777 - val_loss: 0.7282 - val_accuracy: 0.7292 - lr: 0.0100
# Epoch 31/100
# 2728/2732 [============================>.] - ETA: 0s - loss: 0.4791 - accuracy: 0.7796
# Epoch 31: val_loss improved from 0.72815 to 0.66954, saving model to bnn_weights.h5
# 2732/2732 [==============================] - 20s 7ms/step - loss: 0.4790 - accuracy: 0.7796 - val_loss: 0.6695 - val_accuracy: 0.7322 - lr: 0.0100
# Epoch 32/100
# 2727/2732 [============================>.] - ETA: 0s - loss: 0.4685 - accuracy: 0.7826
# Epoch 32: val_loss did not improve from 0.66954
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.4685 - accuracy: 0.7826 - val_loss: 0.6796 - val_accuracy: 0.7350 - lr: 0.0100
# Epoch 33/100
# 2726/2732 [============================>.] - ETA: 0s - loss: 0.4853 - accuracy: 0.7745
# Epoch 33: val_loss improved from 0.66954 to 0.65466, saving model to bnn_weights.h5
# 2732/2732 [==============================] - 20s 7ms/step - loss: 0.4856 - accuracy: 0.7744 - val_loss: 0.6547 - val_accuracy: 0.7247 - lr: 0.0100
# Epoch 34/100
# 2731/2732 [============================>.] - ETA: 0s - loss: 0.4863 - accuracy: 0.7746
# Epoch 34: val_loss did not improve from 0.65466
# 2732/2732 [==============================] - 20s 7ms/step - loss: 0.4862 - accuracy: 0.7746 - val_loss: 0.7058 - val_accuracy: 0.7107 - lr: 0.0100
# Epoch 35/100
# 2728/2732 [============================>.] - ETA: 0s - loss: 0.4690 - accuracy: 0.7852
# Epoch 35: val_loss did not improve from 0.65466
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.4690 - accuracy: 0.7853 - val_loss: 0.8445 - val_accuracy: 0.6745 - lr: 0.0100
# Epoch 36/100
# 2726/2732 [============================>.] - ETA: 0s - loss: 0.4797 - accuracy: 0.7787
# Epoch 36: val_loss did not improve from 0.65466
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.4797 - accuracy: 0.7786 - val_loss: 0.7287 - val_accuracy: 0.7285 - lr: 0.0100
# Epoch 37/100
# 2724/2732 [============================>.] - ETA: 0s - loss: 0.5488 - accuracy: 0.7374
# Epoch 37: val_loss did not improve from 0.65466
# 2732/2732 [==============================] - 20s 7ms/step - loss: 0.5487 - accuracy: 0.7374 - val_loss: 0.8611 - val_accuracy: 0.6697 - lr: 0.0100
# Epoch 38/100
# 2731/2732 [============================>.] - ETA: 0s - loss: 0.5010 - accuracy: 0.7657
# Epoch 38: val_loss did not improve from 0.65466
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.5010 - accuracy: 0.7657 - val_loss: 0.7396 - val_accuracy: 0.7110 - lr: 0.0100
# Epoch 39/100
# 2725/2732 [============================>.] - ETA: 0s - loss: 0.4779 - accuracy: 0.7776
# Epoch 39: val_loss did not improve from 0.65466
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.4779 - accuracy: 0.7777 - val_loss: 0.8856 - val_accuracy: 0.6689 - lr: 0.0100
# Epoch 40/100
# 2727/2732 [============================>.] - ETA: 0s - loss: 0.4917 - accuracy: 0.7713
# Epoch 40: val_loss did not improve from 0.65466
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.4919 - accuracy: 0.7712 - val_loss: 0.8403 - val_accuracy: 0.6784 - lr: 0.0100
# Epoch 41/100
# 2729/2732 [============================>.] - ETA: 0s - loss: 0.4891 - accuracy: 0.7729
# Epoch 41: val_loss did not improve from 0.65466
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.4890 - accuracy: 0.7729 - val_loss: 0.9128 - val_accuracy: 0.6307 - lr: 0.0100
# Epoch 42/100
# 2725/2732 [============================>.] - ETA: 0s - loss: 0.4883 - accuracy: 0.7725
# Epoch 42: val_loss did not improve from 0.65466
# 2732/2732 [==============================] - 20s 7ms/step - loss: 0.4882 - accuracy: 0.7725 - val_loss: 0.8445 - val_accuracy: 0.6751 - lr: 0.0100
# Epoch 43/100
# 2730/2732 [============================>.] - ETA: 0s - loss: 0.4711 - accuracy: 0.7860
# Epoch 43: val_loss did not improve from 0.65466
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.4711 - accuracy: 0.7860 - val_loss: 0.8856 - val_accuracy: 0.6942 - lr: 0.0100
# Epoch 44/100
# 2730/2732 [============================>.] - ETA: 0s - loss: 0.4694 - accuracy: 0.7858
# Epoch 44: val_loss did not improve from 0.65466
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.4694 - accuracy: 0.7858 - val_loss: 0.7607 - val_accuracy: 0.7258 - lr: 0.0100
# Epoch 45/100
# 2729/2732 [============================>.] - ETA: 0s - loss: 0.4800 - accuracy: 0.7756
# Epoch 45: val_loss did not improve from 0.65466
# 2732/2732 [==============================] - 18s 7ms/step - loss: 0.4800 - accuracy: 0.7756 - val_loss: 0.7672 - val_accuracy: 0.7112 - lr: 0.0100
# Epoch 46/100
# 2730/2732 [============================>.] - ETA: 0s - loss: 0.4704 - accuracy: 0.7820
# Epoch 46: val_loss did not improve from 0.65466
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.4704 - accuracy: 0.7820 - val_loss: 0.7795 - val_accuracy: 0.7154 - lr: 0.0100
# Epoch 47/100
# 2723/2732 [============================>.] - ETA: 0s - loss: 0.4823 - accuracy: 0.7757
# Epoch 47: val_loss did not improve from 0.65466
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.4823 - accuracy: 0.7757 - val_loss: 1.0794 - val_accuracy: 0.6301 - lr: 0.0100
# Epoch 48/100
# 2729/2732 [============================>.] - ETA: 0s - loss: 0.4803 - accuracy: 0.7807
# Epoch 48: val_loss did not improve from 0.65466
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.4803 - accuracy: 0.7806 - val_loss: 0.7760 - val_accuracy: 0.7104 - lr: 0.0100
# Epoch 49/100
# 2732/2732 [==============================] - ETA: 0s - loss: 0.4562 - accuracy: 0.7950
# Epoch 49: val_loss did not improve from 0.65466
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.4562 - accuracy: 0.7950 - val_loss: 0.7443 - val_accuracy: 0.7254 - lr: 0.0025
# Epoch 50/100
# 2729/2732 [============================>.] - ETA: 0s - loss: 0.4260 - accuracy: 0.8087
# Epoch 50: val_loss did not improve from 0.65466
# 2732/2732 [==============================] - 20s 7ms/step - loss: 0.4260 - accuracy: 0.8087 - val_loss: 0.6597 - val_accuracy: 0.7566 - lr: 0.0025
# Epoch 51/100
# 2724/2732 [============================>.] - ETA: 0s - loss: 0.4066 - accuracy: 0.8161
# Epoch 51: val_loss did not improve from 0.65466
# 2732/2732 [==============================] - 18s 7ms/step - loss: 0.4068 - accuracy: 0.8160 - val_loss: 0.7572 - val_accuracy: 0.7446 - lr: 0.0025
# Epoch 52/100
# 2732/2732 [==============================] - ETA: 0s - loss: 0.3960 - accuracy: 0.8221
# Epoch 52: val_loss did not improve from 0.65466
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.3960 - accuracy: 0.8221 - val_loss: 0.6936 - val_accuracy: 0.7499 - lr: 0.0025
# Epoch 53/100
# 2727/2732 [============================>.] - ETA: 0s - loss: 0.3896 - accuracy: 0.8224
# Epoch 53: val_loss did not improve from 0.65466
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.3897 - accuracy: 0.8224 - val_loss: 0.6945 - val_accuracy: 0.7318 - lr: 0.0025
# Epoch 54/100
# 2726/2732 [============================>.] - ETA: 0s - loss: 0.3907 - accuracy: 0.8204
# Epoch 54: val_loss improved from 0.65466 to 0.64508, saving model to bnn_weights.h5
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.3906 - accuracy: 0.8204 - val_loss: 0.6451 - val_accuracy: 0.7428 - lr: 0.0025
# Epoch 55/100
# 2730/2732 [============================>.] - ETA: 0s - loss: 0.3807 - accuracy: 0.8260
# Epoch 55: val_loss did not improve from 0.64508
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.3807 - accuracy: 0.8261 - val_loss: 0.6657 - val_accuracy: 0.7290 - lr: 0.0025
# Epoch 56/100
# 2732/2732 [==============================] - ETA: 0s - loss: 0.3864 - accuracy: 0.8281
# Epoch 56: val_loss did not improve from 0.64508
# 2732/2732 [==============================] - 20s 7ms/step - loss: 0.3864 - accuracy: 0.8281 - val_loss: 0.6876 - val_accuracy: 0.7382 - lr: 0.0025
# Epoch 57/100
# 2727/2732 [============================>.] - ETA: 0s - loss: 0.3839 - accuracy: 0.8260
# Epoch 57: val_loss did not improve from 0.64508
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.3840 - accuracy: 0.8259 - val_loss: 0.6625 - val_accuracy: 0.7203 - lr: 0.0025
# Epoch 58/100
# 2732/2732 [==============================] - ETA: 0s - loss: 0.3796 - accuracy: 0.8284
# Epoch 58: val_loss did not improve from 0.64508
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.3796 - accuracy: 0.8284 - val_loss: 0.6980 - val_accuracy: 0.7193 - lr: 0.0025
# Epoch 59/100
# 2727/2732 [============================>.] - ETA: 0s - loss: 0.3740 - accuracy: 0.8304
# Epoch 59: val_loss did not improve from 0.64508
# 2732/2732 [==============================] - 20s 7ms/step - loss: 0.3740 - accuracy: 0.8304 - val_loss: 0.6718 - val_accuracy: 0.7300 - lr: 0.0025
# Epoch 60/100
# 2732/2732 [==============================] - ETA: 0s - loss: 0.3694 - accuracy: 0.8343
# Epoch 60: val_loss did not improve from 0.64508
# 2732/2732 [==============================] - 20s 7ms/step - loss: 0.3694 - accuracy: 0.8343 - val_loss: 0.6705 - val_accuracy: 0.7193 - lr: 0.0025
# Epoch 61/100
# 2724/2732 [============================>.] - ETA: 0s - loss: 0.3739 - accuracy: 0.8322
# Epoch 61: val_loss did not improve from 0.64508
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.3738 - accuracy: 0.8322 - val_loss: 0.6935 - val_accuracy: 0.7213 - lr: 0.0025
# Epoch 62/100
# 2732/2732 [==============================] - ETA: 0s - loss: 0.3761 - accuracy: 0.8316
# Epoch 62: val_loss did not improve from 0.64508
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.3761 - accuracy: 0.8316 - val_loss: 0.6932 - val_accuracy: 0.7219 - lr: 0.0025
# Epoch 63/100
# 2728/2732 [============================>.] - ETA: 0s - loss: 0.3741 - accuracy: 0.8277
# Epoch 63: val_loss did not improve from 0.64508
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.3741 - accuracy: 0.8277 - val_loss: 0.7375 - val_accuracy: 0.6935 - lr: 0.0025
# Epoch 64/100
# 2732/2732 [==============================] - ETA: 0s - loss: 0.3660 - accuracy: 0.8349
# Epoch 64: val_loss did not improve from 0.64508
# 2732/2732 [==============================] - 20s 7ms/step - loss: 0.3660 - accuracy: 0.8349 - val_loss: 0.6999 - val_accuracy: 0.7196 - lr: 0.0025
# Epoch 65/100
# 2727/2732 [============================>.] - ETA: 0s - loss: 0.3705 - accuracy: 0.8303
# Epoch 65: val_loss did not improve from 0.64508
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.3706 - accuracy: 0.8301 - val_loss: 0.7598 - val_accuracy: 0.7007 - lr: 0.0025
# Epoch 66/100
# 2729/2732 [============================>.] - ETA: 0s - loss: 0.3688 - accuracy: 0.8322
# Epoch 66: val_loss did not improve from 0.64508
# 2732/2732 [==============================] - 20s 7ms/step - loss: 0.3687 - accuracy: 0.8322 - val_loss: 0.6963 - val_accuracy: 0.7159 - lr: 0.0025
# Epoch 67/100
# 2731/2732 [============================>.] - ETA: 0s - loss: 0.3637 - accuracy: 0.8351
# Epoch 67: val_loss did not improve from 0.64508
# 2732/2732 [==============================] - 20s 7ms/step - loss: 0.3636 - accuracy: 0.8351 - val_loss: 0.7129 - val_accuracy: 0.7154 - lr: 0.0025
# Epoch 68/100
# 2728/2732 [============================>.] - ETA: 0s - loss: 0.3586 - accuracy: 0.8368
# Epoch 68: val_loss did not improve from 0.64508
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.3587 - accuracy: 0.8368 - val_loss: 0.7061 - val_accuracy: 0.7252 - lr: 0.0025
# Epoch 69/100
# 2728/2732 [============================>.] - ETA: 0s - loss: 0.3594 - accuracy: 0.8348
# Epoch 69: val_loss did not improve from 0.64508
#
# Epoch 69: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.3594 - accuracy: 0.8349 - val_loss: 0.6604 - val_accuracy: 0.7247 - lr: 0.0025
# Epoch 70/100
# 2727/2732 [============================>.] - ETA: 0s - loss: 0.3534 - accuracy: 0.8385
# Epoch 70: val_loss did not improve from 0.64508
# 2732/2732 [==============================] - 20s 7ms/step - loss: 0.3533 - accuracy: 0.8385 - val_loss: 0.6710 - val_accuracy: 0.7218 - lr: 6.2500e-04
# Epoch 71/100
# 2730/2732 [============================>.] - ETA: 0s - loss: 0.3502 - accuracy: 0.8405
# Epoch 71: val_loss did not improve from 0.64508
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.3502 - accuracy: 0.8405 - val_loss: 0.6624 - val_accuracy: 0.7237 - lr: 6.2500e-04
# Epoch 72/100
# 2725/2732 [============================>.] - ETA: 0s - loss: 0.3472 - accuracy: 0.8421
# Epoch 72: val_loss did not improve from 0.64508
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.3471 - accuracy: 0.8422 - val_loss: 0.6866 - val_accuracy: 0.7193 - lr: 6.2500e-04
# Epoch 73/100
# 2727/2732 [============================>.] - ETA: 0s - loss: 0.3454 - accuracy: 0.8407
# Epoch 73: val_loss did not improve from 0.64508
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.3453 - accuracy: 0.8408 - val_loss: 0.6571 - val_accuracy: 0.7294 - lr: 6.2500e-04
# Epoch 74/100
# 2727/2732 [============================>.] - ETA: 0s - loss: 0.3439 - accuracy: 0.8441
# Epoch 74: val_loss did not improve from 0.64508
# 2732/2732 [==============================] - 20s 7ms/step - loss: 0.3440 - accuracy: 0.8441 - val_loss: 0.6547 - val_accuracy: 0.7268 - lr: 6.2500e-04
# Epoch 75/100
# 2731/2732 [============================>.] - ETA: 0s - loss: 0.3416 - accuracy: 0.8445
# Epoch 75: val_loss did not improve from 0.64508
# 2732/2732 [==============================] - 21s 8ms/step - loss: 0.3416 - accuracy: 0.8445 - val_loss: 0.6939 - val_accuracy: 0.7189 - lr: 6.2500e-04
# Epoch 76/100
# 2726/2732 [============================>.] - ETA: 0s - loss: 0.3422 - accuracy: 0.8446
# Epoch 76: val_loss did not improve from 0.64508
# 2732/2732 [==============================] - 20s 7ms/step - loss: 0.3424 - accuracy: 0.8445 - val_loss: 0.6576 - val_accuracy: 0.7270 - lr: 6.2500e-04
# Epoch 77/100
# 2728/2732 [============================>.] - ETA: 0s - loss: 0.3417 - accuracy: 0.8439
# Epoch 77: val_loss did not improve from 0.64508
# 2732/2732 [==============================] - 21s 8ms/step - loss: 0.3415 - accuracy: 0.8439 - val_loss: 0.6613 - val_accuracy: 0.7302 - lr: 6.2500e-04
# Epoch 78/100
# 2727/2732 [============================>.] - ETA: 0s - loss: 0.3416 - accuracy: 0.8456
# Epoch 78: val_loss did not improve from 0.64508
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.3415 - accuracy: 0.8456 - val_loss: 0.6700 - val_accuracy: 0.7226 - lr: 6.2500e-04
# Epoch 79/100
# 2731/2732 [============================>.] - ETA: 0s - loss: 0.3417 - accuracy: 0.8449
# Epoch 79: val_loss did not improve from 0.64508
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.3416 - accuracy: 0.8449 - val_loss: 0.6881 - val_accuracy: 0.7169 - lr: 6.2500e-04
# Epoch 80/100
# 2724/2732 [============================>.] - ETA: 0s - loss: 0.3384 - accuracy: 0.8468
# Epoch 80: val_loss did not improve from 0.64508
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.3385 - accuracy: 0.8468 - val_loss: 0.6526 - val_accuracy: 0.7220 - lr: 6.2500e-04
# Epoch 81/100
# 2727/2732 [============================>.] - ETA: 0s - loss: 0.3409 - accuracy: 0.8443
# Epoch 81: val_loss improved from 0.64508 to 0.64333, saving model to bnn_weights.h5
# 2732/2732 [==============================] - 20s 7ms/step - loss: 0.3409 - accuracy: 0.8443 - val_loss: 0.6433 - val_accuracy: 0.7349 - lr: 6.2500e-04
# Epoch 82/100
# 2725/2732 [============================>.] - ETA: 0s - loss: 0.3367 - accuracy: 0.8474
# Epoch 82: val_loss did not improve from 0.64333
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.3365 - accuracy: 0.8474 - val_loss: 0.6574 - val_accuracy: 0.7289 - lr: 6.2500e-04
# Epoch 83/100
# 2727/2732 [============================>.] - ETA: 0s - loss: 0.3376 - accuracy: 0.8457
# Epoch 83: val_loss did not improve from 0.64333
# 2732/2732 [==============================] - 20s 7ms/step - loss: 0.3377 - accuracy: 0.8456 - val_loss: 0.6575 - val_accuracy: 0.7254 - lr: 6.2500e-04
# Epoch 84/100
# 2730/2732 [============================>.] - ETA: 0s - loss: 0.3416 - accuracy: 0.8443
# Epoch 84: val_loss did not improve from 0.64333
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.3416 - accuracy: 0.8443 - val_loss: 0.6721 - val_accuracy: 0.7231 - lr: 6.2500e-04
# Epoch 85/100
# 2723/2732 [============================>.] - ETA: 0s - loss: 0.3381 - accuracy: 0.8456
# Epoch 85: val_loss did not improve from 0.64333
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.3380 - accuracy: 0.8456 - val_loss: 0.6679 - val_accuracy: 0.7240 - lr: 6.2500e-04
# Epoch 86/100
# 2730/2732 [============================>.] - ETA: 0s - loss: 0.3370 - accuracy: 0.8467
# Epoch 86: val_loss did not improve from 0.64333
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.3371 - accuracy: 0.8467 - val_loss: 0.6583 - val_accuracy: 0.7248 - lr: 6.2500e-04
# Epoch 87/100
# 2730/2732 [============================>.] - ETA: 0s - loss: 0.3360 - accuracy: 0.8468
# Epoch 87: val_loss improved from 0.64333 to 0.63075, saving model to bnn_weights.h5
# 2732/2732 [==============================] - 20s 7ms/step - loss: 0.3359 - accuracy: 0.8468 - val_loss: 0.6307 - val_accuracy: 0.7313 - lr: 6.2500e-04
# Epoch 88/100
# 2730/2732 [============================>.] - ETA: 0s - loss: 0.3330 - accuracy: 0.8482
# Epoch 88: val_loss did not improve from 0.63075
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.3331 - accuracy: 0.8481 - val_loss: 0.6450 - val_accuracy: 0.7370 - lr: 6.2500e-04
# Epoch 89/100
# 2726/2732 [============================>.] - ETA: 0s - loss: 0.3362 - accuracy: 0.8473
# Epoch 89: val_loss did not improve from 0.63075
# 2732/2732 [==============================] - 20s 7ms/step - loss: 0.3363 - accuracy: 0.8473 - val_loss: 0.6603 - val_accuracy: 0.7273 - lr: 6.2500e-04
# Epoch 90/100
# 2732/2732 [==============================] - ETA: 0s - loss: 0.3362 - accuracy: 0.8484
# Epoch 90: val_loss did not improve from 0.63075
# 2732/2732 [==============================] - 23s 9ms/step - loss: 0.3362 - accuracy: 0.8484 - val_loss: 0.6442 - val_accuracy: 0.7333 - lr: 6.2500e-04
# Epoch 91/100
# 2725/2732 [============================>.] - ETA: 0s - loss: 0.3373 - accuracy: 0.8477
# Epoch 91: val_loss did not improve from 0.63075
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.3373 - accuracy: 0.8477 - val_loss: 0.6738 - val_accuracy: 0.7245 - lr: 6.2500e-04
# Epoch 92/100
# 2724/2732 [============================>.] - ETA: 0s - loss: 0.3335 - accuracy: 0.8472
# Epoch 92: val_loss did not improve from 0.63075
# 2732/2732 [==============================] - 20s 7ms/step - loss: 0.3336 - accuracy: 0.8472 - val_loss: 0.6371 - val_accuracy: 0.7389 - lr: 6.2500e-04
# Epoch 93/100
# 2729/2732 [============================>.] - ETA: 0s - loss: 0.3342 - accuracy: 0.8453
# Epoch 93: val_loss did not improve from 0.63075
# 2732/2732 [==============================] - 20s 7ms/step - loss: 0.3341 - accuracy: 0.8453 - val_loss: 0.6411 - val_accuracy: 0.7321 - lr: 6.2500e-04
# Epoch 94/100
# 2726/2732 [============================>.] - ETA: 0s - loss: 0.3376 - accuracy: 0.8446
# Epoch 94: val_loss did not improve from 0.63075
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.3375 - accuracy: 0.8445 - val_loss: 0.6549 - val_accuracy: 0.7315 - lr: 6.2500e-04
# Epoch 95/100
# 2729/2732 [============================>.] - ETA: 0s - loss: 0.3346 - accuracy: 0.8473
# Epoch 95: val_loss did not improve from 0.63075
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.3346 - accuracy: 0.8473 - val_loss: 0.6703 - val_accuracy: 0.7276 - lr: 6.2500e-04
# Epoch 96/100
# 2731/2732 [============================>.] - ETA: 0s - loss: 0.3333 - accuracy: 0.8469
# Epoch 96: val_loss did not improve from 0.63075
# 2732/2732 [==============================] - 20s 7ms/step - loss: 0.3333 - accuracy: 0.8469 - val_loss: 0.6474 - val_accuracy: 0.7315 - lr: 6.2500e-04
# Epoch 97/100
# 2726/2732 [============================>.] - ETA: 0s - loss: 0.3320 - accuracy: 0.8483
# Epoch 97: val_loss did not improve from 0.63075
# 2732/2732 [==============================] - 22s 8ms/step - loss: 0.3320 - accuracy: 0.8483 - val_loss: 0.6436 - val_accuracy: 0.7420 - lr: 6.2500e-04
# Epoch 98/100
# 2732/2732 [==============================] - ETA: 0s - loss: 0.3331 - accuracy: 0.8477
# Epoch 98: val_loss did not improve from 0.63075
# 2732/2732 [==============================] - 20s 7ms/step - loss: 0.3331 - accuracy: 0.8477 - val_loss: 0.6397 - val_accuracy: 0.7324 - lr: 6.2500e-04
# Epoch 99/100
# 2727/2732 [============================>.] - ETA: 0s - loss: 0.3330 - accuracy: 0.8476
# Epoch 99: val_loss did not improve from 0.63075
# 2732/2732 [==============================] - 21s 8ms/step - loss: 0.3331 - accuracy: 0.8476 - val_loss: 0.6349 - val_accuracy: 0.7379 - lr: 6.2500e-04
# Epoch 100/100
# 2724/2732 [============================>.] - ETA: 0s - loss: 0.3335 - accuracy: 0.8481
# Epoch 100: val_loss improved from 0.63075 to 0.61736, saving model to bnn_weights.h5
# 2732/2732 [==============================] - 19s 7ms/step - loss: 0.3335 - accuracy: 0.8480 - val_loss: 0.6174 - val_accuracy: 0.7453 - lr: 6.2500e-04

# %%
# Evaluate the accuracy of the BNN model

print(bnn_model.evaluate(X_train_scaled, Y_train))
print(bnn_model.evaluate(X_test_scaled, Y_test))
# Out:
# 3415/3415 [==============================] - 14s 4ms/step - loss: 0.3987 - accuracy: 0.8260
# [0.39867860078811646, 0.826046347618103]
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.5623 - accuracy: 0.7478
# [0.5623340010643005, 0.7477930784225464]

# %% [markdown]
# ## Advanced: Plotting uncertainty metrics obtained from the BNN predictions
#
# Below we provide some functions to plot the results of your BNN and assess its performance

# %%
# Define functions to analyse model predictions versus true labels

def boxplot_model_predictions(prob_predictions, point_num, labels, run_ensemble = True):
    # Print the true activity
    print('------------------------------')
    print('True cluster:', labels[point_num])
    print('')

    # Print the probabilities the model assigns
    print('------------------------------')
    print('Model estimated probabilities:')
    # Create ensemble of predicted probabilities

    predicted_probabilities = prob_predictions[:, point_num, :]
    box = plt.boxplot(predicted_probabilities, positions = [0, 1, 2, 3, 4, 5])
    for i in range(6):
        if i == int(labels[point_num]):
            plt.setp(box['boxes'][i], color='green')
            plt.setp(box['medians'][i], color='green')
        else:
            plt.setp(box['boxes'][i], color='purple')
            plt.setp(box['medians'][i], color='purple')
    plt.ylim([0, 1])
    plt.ylabel('Probability')
    plt.xticks([0, 1, 2, 3, 4, 5], ["F", "E", "D", "C", "B", "A"])
    plt.xlim([5.5, -0.5])
    plt.show()        
    return predicted_probabilities
    
def get_correct_indices(prob_mean, labels):
    correct = np.argmax(prob_mean, axis=1) == np.argmax(labels, axis = 1)
    correct_indices = [i for i in range(prob_mean.shape[0]) if correct[i]]
    incorrect_indices = [i for i in range(prob_mean.shape[0]) if not correct[i]]
    return correct_indices, incorrect_indices

def plot_entropy_distribution(prob_mean, labels):
    entropy = -np.sum(prob_mean * np.log2(prob_mean), axis=1)
    corr_indices, incorr_indices = get_correct_indices(prob_mean, labels)
    indices = [corr_indices, incorr_indices]
    fig, axes = plt.subplots(1, 2, figsize=(10, 4))
    for i, category in zip(range(2), ['Correct', 'Incorrect']):
        entropy_category = np.array([entropy[j] for j in indices[i]])
        mean_entropy = np.mean(entropy_category[~np.isnan(entropy_category)])
        num_samples = entropy_category.shape[0]
        #title = category + 'ly labelled ({:.2f}% of total)'.format(num_samples / x.shape[0] * 100)
        title = category + 'ly labelled'.format(num_samples / x.shape[0] * 100)
        axes[i].hist(entropy_category, weights=(1/num_samples)*np.ones(num_samples))
        axes[i].annotate('Mean: {:.3f}'.format(mean_entropy), (0.4, 0.9), ha='center')
        axes[i].set_xlabel('Entropy')
        axes[i].set_ylim([0, 1])
        #axes[i].set_ylabel('Probability')
        axes[i].set_title(title)
        print(num_samples)
    plt.show()

# %%
# Generate ensemble of predictions from the BNN

ensemble_size = 200
x = X_test_scaled

prob_predictions = np.empty(shape=(ensemble_size, 40328, 6))
for i in range(ensemble_size):
    prob_predictions[i] = bnn_model(x).mean().numpy()

prob_mean = prob_predictions.mean(axis = 0)

# reshape array
pred = np.nan * np.zeros((360*720))
pred[maskTest.flatten()] = prob_mean.argmax(axis = 1)

# %%
# find indices of datapoints for which the neural network is correct and indices for which it is incorrect
c_in, inc_in = get_correct_indices(prob_mean, Y_test)

# %% [markdown]
# #### Example of two output distributions predicted by BNN

# %%
plt.rcParams["figure.figsize"] = (6.4, 4.8)

## two correct prediction
corr_0 = boxplot_model_predictions(prob_predictions, c_in[107*200], test_label, run_ensemble = True)
corr_1 = boxplot_model_predictions(prob_predictions, c_in[75*200], test_label, run_ensemble = True)

## two incorrect predictions
incorr_0 = boxplot_model_predictions(prob_predictions, inc_in[100], test_label, run_ensemble = True)
incorr_1 = boxplot_model_predictions(prob_predictions, inc_in[200], test_label, run_ensemble = True)

# Note in these box and whisker plots the distributions themselves represent the aleatoric uncertainty 
# and the box and whiskers (ie. the ensemble of possible distributions) represent the epistemic uncertainty
# Out:
# ------------------------------
# True cluster: 5.0
#
# ------------------------------
# Model estimated probabilities:
# ------------------------------
# True cluster: 0.0
#
# ------------------------------
# Model estimated probabilities:
# ------------------------------
# True cluster: 4.0
#
# ------------------------------
# Model estimated probabilities:
# ------------------------------
# True cluster: 5.0
#
# ------------------------------
# Model estimated probabilities:

# %% [markdown]
# #### Uncertainty quantification using entropy
#
# Model uncertainty can be quantified by calculating the [entropy](https://en.wikipedia.org/wiki/Entropy_%28information_theory%29) of the distribution. The higher the value, the more unsure the model is

# %%
! pip install Basemap # note you may have this already installed and therefore do not need to run this line
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Basemap
#   Downloading basemap-1.3.6-cp310-cp310-manylinux1_x86_64.whl (859 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 859.2/859.2 kB 14.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.10/dist-packages (from Basemap) (1.22.4)
# Collecting pyproj<3.5.0,>=1.9.3
#   Downloading pyproj-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 91.9 MB/s eta 0:00:00
# Collecting matplotlib<3.7,>=1.5
#   Downloading matplotlib-3.6.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 84.3 MB/s eta 0:00:00
# Collecting basemap-data<1.4,>=1.3.2
#   Downloading basemap_data-1.3.2-py2.py3-none-any.whl (30.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.5/30.5 MB 19.3 MB/s eta 0:00:00
# Collecting pyshp<2.4,>=1.2
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.7,>=1.5->Basemap) (1.0.7)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.7,>=1.5->Basemap) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.7,>=1.5->Basemap) (4.39.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.7,>=1.5->Basemap) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.7,>=1.5->Basemap) (23.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.7,>=1.5->Basemap) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.7,>=1.5->Basemap) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.7,>=1.5->Basemap) (1.4.4)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyproj<3.5.0,>=1.9.3->Basemap) (2022.12.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib<3.7,>=1.5->Basemap) (1.16.0)
# Installing collected packages: pyshp, pyproj, basemap-data, matplotlib, Basemap
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
# Successfully installed Basemap-1.3.6 basemap-data-1.3.2 matplotlib-3.6.3 pyproj-3.4.1 pyshp-2.3.1

# %%
from mpl_toolkits.basemap import * 

plt.rcParams.update({'font.size': 16})

entropy = -np.sum(prob_mean* np.log2(prob_mean), axis=1)
all_results = np.nan * np.zeros((360*720))
all_results[maskTest.flatten()] = entropy
lat = monthly_ssh['lat']
lon = monthly_ssh['lon']
lons = lon[1,:].values
lats = lat[:,1].values
llons, llats = np.meshgrid(lons,lats)
fig, ax = plt.subplots(figsize = (12, 6))
m = Basemap(llcrnrlon=-80, urcrnrlon=20, llcrnrlat=-80, urcrnrlat=89, projection='mill', resolution='l')
m.drawmapboundary(fill_color='0.9')
m.drawparallels(np.arange(-90.,99.,30.),labels=[1,1,0,1])
m.drawmeridians(np.arange(-180.,180.,60.),labels=[0,0,0,1])
m.drawcoastlines()
m.fillcontinents()
im1 = m.pcolor(llons, llats, np.flipud(np.reshape(all_results,(360,720)))[::-1,:], latlon=True, cmap = plt.cm.Oranges)
cbar = plt.colorbar(pad=0.075)
cbar.set_label('Entropy')
im2 = m.scatter([-63.25], [23.75], marker = 'D', c = 'black',  s = 50, latlon = True)
im3 = m.scatter([-4.25], [-12.75], marker = 'D', c = 'blue',  s = 50, latlon = True)
im4 = m.scatter([-37.25], [-17.25], marker = 'D', c = 'magenta', s = 50, latlon = True)
plt.show()

# %%
## For a robust trustworthy BNN, we would expect the correct predictions to have a low entropy ie. a low uncertainty, and the incorrect predictions to have a
## high entropy ie. a high uncertainty. 
## This is desirable because in simple terms, it means that the BNN is more certain of its prediction when it is correct than when it is incorrect
plot_entropy_distribution(prob_mean, Y_test)
# Out:
# 31946
# 8382

# %% [markdown]
# There are also many other interesting plots that can be produced from BNN predictions as shown in Clare et al. 2022.
# The code to make these plots is at the end of this [notebook on github](https://github.com/maikejulie/DNN4Cli/blob/main/THOR/BayesianApproach/THOR%20-%20Step_2_Bayesian_approach.ipynb)
